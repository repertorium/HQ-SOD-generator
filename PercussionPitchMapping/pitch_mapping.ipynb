# %%
import pretty_midi
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import yaml

from pitch_mapping import pitch_distances, valid_pitch_selection, pitch_mapping, NoUntunedPercussionTrackFound

with open('./valid_pitches.yaml','r') as f:
    valid_pitches = yaml.safe_load(f)

# %%
note_pitches = np.random.randint(0,127,100)
note_pitches
# Out:
# array([ 10, 111,  11,  62,  18,  10,  99,  40, 109,  26,  86,  40,  23,
#         23,  53,  53,  26,  78,   9, 120,  65,  99,  54,  28,  48,  13,
#         48,  69,  40,   8,  77,  82,  90,  36, 117,  35,  88,  57,   0,
#         20,   5, 115,  29,  93, 110, 111,  14,  47,  83,  49,  60, 123,
#         44,  74,  67,  11,  90,  52, 122,  35,  16,  29,  73,  33,  34,
#          7,  65,  84,   6,   5,  34,  78,  66, 116, 101,   0,  40,  12,
#         24,   7, 122,  80, 125,  12,  75,  72,   8,  61,  11, 110, 110,
#         78,  18,  35,  46,  80,  35,  41, 111,  10])

# %%
instrument_valid_pitches = np.array(valid_pitches[100]['Valid_pitches'])
instrument_valid_pitches
# Out:
# array([48, 50, 52, 53])

# %%
distances = pitch_distances(note_pitches[0],instrument_valid_pitches)
note_valid_pitch = valid_pitch_selection(instrument_valid_pitches,distances)
print(distances)
print(f'Note pitch = {note_pitches[0]}')
print(f'Minimum distance = {distances.min()}')
print(f'Note valid pitch = {note_valid_pitch}')
# Out:
# [[38 40 42 43]
#  [26 28 30 31]
#  [14 16 18 19]
#  [ 2  4  6  7]
#  [10  8  6  5]
#  [22 20 18 17]
#  [34 32 30 29]
#  [46 44 42 41]
#  [58 56 54 53]
#  [70 68 66 65]]
# Note pitch = 10
# Minimum distance = 2
# Note valid pitch = 48

# %%
for n,note_pitch in enumerate(note_pitches):
    distances = pitch_distances(note_pitch,instrument_valid_pitches)
    note_valid_pitch = valid_pitch_selection(instrument_valid_pitches,distances)
    print(f'Note number {n+1}>> minimum distance = {distances.min()}, valid_pitch = {note_valid_pitch}')
# Out:
# Note number 1>> minimum distance = 2, valid_pitch = 48
# Note number 2>> minimum distance = 1, valid_pitch = 50
# Note number 3>> minimum distance = 1, valid_pitch = 48
# Note number 4>> minimum distance = 0, valid_pitch = 50
# Note number 5>> minimum distance = 1, valid_pitch = 53
# Note number 6>> minimum distance = 2, valid_pitch = 48
# Note number 7>> minimum distance = 1, valid_pitch = 50
# Note number 8>> minimum distance = 0, valid_pitch = 52
# Note number 9>> minimum distance = 1, valid_pitch = 48
# Note number 10>> minimum distance = 0, valid_pitch = 50
# Note number 11>> minimum distance = 0, valid_pitch = 50
# Note number 12>> minimum distance = 0, valid_pitch = 52
# Note number 13>> minimum distance = 1, valid_pitch = 48
# Note number 14>> minimum distance = 1, valid_pitch = 48
# Note number 15>> minimum distance = 0, valid_pitch = 53
# Note number 16>> minimum distance = 0, valid_pitch = 53
# Note number 17>> minimum distance = 0, valid_pitch = 50
# Note number 18>> minimum distance = 1, valid_pitch = 53
# Note number 19>> minimum distance = 3, valid_pitch = 48
# Note number 20>> minimum distance = 0, valid_pitch = 48
# Note number 21>> minimum distance = 0, valid_pitch = 53
# Note number 22>> minimum distance = 1, valid_pitch = 50
# Note number 23>> minimum distance = 1, valid_pitch = 53
# Note number 24>> minimum distance = 0, valid_pitch = 52
# Note number 25>> minimum distance = 0, valid_pitch = 48
# Note number 26>> minimum distance = 1, valid_pitch = 48
# Note number 27>> minimum distance = 0, valid_pitch = 48
# Note number 28>> minimum distance = 3, valid_pitch = 48
# Note number 29>> minimum distance = 0, valid_pitch = 52
# Note number 30>> minimum distance = 3, valid_pitch = 53
# Note number 31>> minimum distance = 0, valid_pitch = 53
# Note number 32>> minimum distance = 2, valid_pitch = 48
# Note number 33>> minimum distance = 1, valid_pitch = 53
# Note number 34>> minimum distance = 0, valid_pitch = 48
# Note number 35>> minimum distance = 3, valid_pitch = 48
# Note number 36>> minimum distance = 1, valid_pitch = 48
# Note number 37>> minimum distance = 0, valid_pitch = 52
# Note number 38>> minimum distance = 3, valid_pitch = 48
# Note number 39>> minimum distance = 0, valid_pitch = 48
# Note number 40>> minimum distance = 3, valid_pitch = 53
# Note number 41>> minimum distance = 0, valid_pitch = 53
# Note number 42>> minimum distance = 2, valid_pitch = 53
# Note number 43>> minimum distance = 0, valid_pitch = 53
# Note number 44>> minimum distance = 3, valid_pitch = 48
# Note number 45>> minimum distance = 0, valid_pitch = 50
# Note number 46>> minimum distance = 1, valid_pitch = 50
# Note number 47>> minimum distance = 0, valid_pitch = 50
# Note number 48>> minimum distance = 1, valid_pitch = 48
# Note number 49>> minimum distance = 1, valid_pitch = 48
# Note number 50>> minimum distance = 1, valid_pitch = 48
# Note number 51>> minimum distance = 0, valid_pitch = 48
# Note number 52>> minimum distance = 1, valid_pitch = 50
# Note number 53>> minimum distance = 3, valid_pitch = 53
# Note number 54>> minimum distance = 0, valid_pitch = 50
# Note number 55>> minimum distance = 2, valid_pitch = 53
# Note number 56>> minimum distance = 1, valid_pitch = 48
# Note number 57>> minimum distance = 1, valid_pitch = 53
# Note number 58>> minimum distance = 0, valid_pitch = 52
# Note number 59>> minimum distance = 0, valid_pitch = 50
# Note number 60>> minimum distance = 1, valid_pitch = 48
# Note number 61>> minimum distance = 0, valid_pitch = 52
# Note number 62>> minimum distance = 0, valid_pitch = 53
# Note number 63>> minimum distance = 1, valid_pitch = 48
# Note number 64>> minimum distance = 3, valid_pitch = 48
# Note number 65>> minimum distance = 2, valid_pitch = 48
# Note number 66>> minimum distance = 2, valid_pitch = 53
# Note number 67>> minimum distance = 0, valid_pitch = 53
# Note number 68>> minimum distance = 0, valid_pitch = 48
# Note number 69>> minimum distance = 1, valid_pitch = 53
# Note number 70>> minimum distance = 0, valid_pitch = 53
# Note number 71>> minimum distance = 2, valid_pitch = 48
# Note number 72>> minimum distance = 1, valid_pitch = 53
# Note number 73>> minimum distance = 1, valid_pitch = 53
# Note number 74>> minimum distance = 3, valid_pitch = 53
# Note number 75>> minimum distance = 0, valid_pitch = 53
# Note number 76>> minimum distance = 0, valid_pitch = 48
# Note number 77>> minimum distance = 0, valid_pitch = 52
# Note number 78>> minimum distance = 0, valid_pitch = 48
# Note number 79>> minimum distance = 0, valid_pitch = 48
# Note number 80>> minimum distance = 2, valid_pitch = 53
# Note number 81>> minimum distance = 0, valid_pitch = 50
# Note number 82>> minimum distance = 3, valid_pitch = 53
# Note number 83>> minimum distance = 0, valid_pitch = 53
# Note number 84>> minimum distance = 0, valid_pitch = 48
# Note number 85>> minimum distance = 1, valid_pitch = 50
# Note number 86>> minimum distance = 0, valid_pitch = 48
# Note number 87>> minimum distance = 3, valid_pitch = 53
# Note number 88>> minimum distance = 1, valid_pitch = 48
# Note number 89>> minimum distance = 1, valid_pitch = 48
# Note number 90>> minimum distance = 0, valid_pitch = 50
# Note number 91>> minimum distance = 0, valid_pitch = 50
# Note number 92>> minimum distance = 1, valid_pitch = 53
# Note number 93>> minimum distance = 1, valid_pitch = 53
# Note number 94>> minimum distance = 1, valid_pitch = 48
# Note number 95>> minimum distance = 2, valid_pitch = 48
# Note number 96>> minimum distance = 3, valid_pitch = 53
# Note number 97>> minimum distance = 1, valid_pitch = 48
# Note number 98>> minimum distance = 0, valid_pitch = 53
# Note number 99>> minimum distance = 1, valid_pitch = 50
# Note number 100>> minimum distance = 2, valid_pitch = 48

# %%
midifiles = [file for file in pathlib.Path('../../targetMIDI/MIDI/expressiveSOD/Kunstderfuge/').glob('*')]

midi_data = pretty_midi.PrettyMIDI(str(midifiles[13]))

try:
    mapped_midi_data = pitch_mapping(midi_data,valid_pitches)
except NoUntunedPercussionTrackFound:
    print('No untuned percussion in this file')

# %%
untuned_percussion_index = [instrument.name for instrument in midi_data.instruments].index('untunedpercussion')
for n in range(len(mapped_midi_data.instruments[untuned_percussion_index].notes)):
    original_pitch = midi_data.instruments[untuned_percussion_index].notes[n].pitch
    mapped_pitch = mapped_midi_data.instruments[untuned_percussion_index].notes[n].pitch
    print(f'Note {n+1}>> Original pitch: {original_pitch}, Mapped pitch: {mapped_pitch}')
# Out:
# Note 1>> Original pitch: 38, Mapped pitch: 50
# Note 2>> Original pitch: 38, Mapped pitch: 50
# Note 3>> Original pitch: 38, Mapped pitch: 50
# Note 4>> Original pitch: 38, Mapped pitch: 50
# Note 5>> Original pitch: 38, Mapped pitch: 50
# Note 6>> Original pitch: 38, Mapped pitch: 50
# Note 7>> Original pitch: 38, Mapped pitch: 50
# Note 8>> Original pitch: 38, Mapped pitch: 50
# Note 9>> Original pitch: 38, Mapped pitch: 50
# Note 10>> Original pitch: 38, Mapped pitch: 50
# Note 11>> Original pitch: 38, Mapped pitch: 50
# Note 12>> Original pitch: 38, Mapped pitch: 50
# Note 13>> Original pitch: 38, Mapped pitch: 50
# Note 14>> Original pitch: 38, Mapped pitch: 50
# Note 15>> Original pitch: 38, Mapped pitch: 50
# Note 16>> Original pitch: 38, Mapped pitch: 50
# Note 17>> Original pitch: 38, Mapped pitch: 50
# Note 18>> Original pitch: 38, Mapped pitch: 50
# Note 19>> Original pitch: 38, Mapped pitch: 50
# Note 20>> Original pitch: 38, Mapped pitch: 50
# Note 21>> Original pitch: 38, Mapped pitch: 50
# Note 22>> Original pitch: 38, Mapped pitch: 50
# Note 23>> Original pitch: 38, Mapped pitch: 50
# Note 24>> Original pitch: 38, Mapped pitch: 50
# Note 25>> Original pitch: 38, Mapped pitch: 50
# Note 26>> Original pitch: 38, Mapped pitch: 50
# Note 27>> Original pitch: 38, Mapped pitch: 50
# Note 28>> Original pitch: 38, Mapped pitch: 50
# Note 29>> Original pitch: 38, Mapped pitch: 50
# Note 30>> Original pitch: 38, Mapped pitch: 50
# Note 31>> Original pitch: 38, Mapped pitch: 50
# Note 32>> Original pitch: 38, Mapped pitch: 50
# Note 33>> Original pitch: 38, Mapped pitch: 50
# Note 34>> Original pitch: 38, Mapped pitch: 50
# Note 35>> Original pitch: 38, Mapped pitch: 50
# Note 36>> Original pitch: 38, Mapped pitch: 50
# Note 37>> Original pitch: 38, Mapped pitch: 50
# Note 38>> Original pitch: 38, Mapped pitch: 50
# Note 39>> Original pitch: 38, Mapped pitch: 50
# Note 40>> Original pitch: 38, Mapped pitch: 50
# Note 41>> Original pitch: 38, Mapped pitch: 50
# Note 42>> Original pitch: 38, Mapped pitch: 50
# Note 43>> Original pitch: 38, Mapped pitch: 50
# Note 44>> Original pitch: 38, Mapped pitch: 50
# Note 45>> Original pitch: 38, Mapped pitch: 50
# Note 46>> Original pitch: 38, Mapped pitch: 50
# Note 47>> Original pitch: 38, Mapped pitch: 50
# Note 48>> Original pitch: 38, Mapped pitch: 50
# Note 49>> Original pitch: 38, Mapped pitch: 50
# Note 50>> Original pitch: 38, Mapped pitch: 50
# Note 51>> Original pitch: 38, Mapped pitch: 50
# Note 52>> Original pitch: 38, Mapped pitch: 50
# Note 53>> Original pitch: 49, Mapped pitch: 49
# Note 54>> Original pitch: 51, Mapped pitch: 51
# Note 55>> Original pitch: 55, Mapped pitch: 55
# Note 56>> Original pitch: 49, Mapped pitch: 49
# Note 57>> Original pitch: 51, Mapped pitch: 51
# Note 58>> Original pitch: 55, Mapped pitch: 55
# Note 59>> Original pitch: 49, Mapped pitch: 49
# Note 60>> Original pitch: 51, Mapped pitch: 51
# Note 61>> Original pitch: 55, Mapped pitch: 55
# Note 62>> Original pitch: 49, Mapped pitch: 49
